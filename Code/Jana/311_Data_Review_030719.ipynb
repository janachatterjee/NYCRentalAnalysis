# %%
#------------------------------------------------#
# Dependencies
#------------------------------------------------#
import os
import csv
import pandas as pd
import numpy as np
import json 
import requests
import random
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
from matplotlib.font_manager import FontProperties
from scipy.misc import imread
import matplotlib.image as mpimg

# %%
#------------------------------------------------#
# CSV Time
#------------------------------------------------#

# Store the CSV filepath in a variable
the311 = "Resources/Merged3112018Data.csv"

# Now, read the data from the 311 CSV into a DataFrame
the311_df = pd.read_csv(the311, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# Preview the DataFrame, but only 20 rows
the311_df.head(20)
# Out:
#    Unique Key      Month     Created Date  \
# 0    39404080       June   6/8/2018 13:59
# 1    39406030       June   6/8/2018 14:08
# 2    39716202       July  7/12/2018 22:20
# 3    41102839   December   12/4/2018 8:57
# 4    39726709       July   7/13/2018 7:24
# 5    39739517       July  7/15/2018 15:24
# 6    39415071       June   6/9/2018 23:49
# 7    39424257       June  6/10/2018 22:04
# 8    39426862       June   6/11/2018 1:14
# 9    39437040       June  6/11/2018 19:39
# 10   39994038     August  8/12/2018 20:00
# 11   40269290  September  9/13/2018 12:03
# 12   39470862       June   6/15/2018 9:42
# 13   40048424     August  8/18/2018 12:13
# 14   39064738      April  4/30/2018 10:24
# 15   39733346       July   7/14/2018 8:47
# 16   39482406       June  6/16/2018 19:50
# 17   39483029       June  6/16/2018 16:50
# 18   40015636     August  8/15/2018 17:06
# 19   39484836       June  6/16/2018 23:20
#
#                                 Agency Name               Complaint Type  \
# 0           New York City Police Department  Non-Emergency Police Matter
# 1           New York City Police Department              Illegal Parking
# 2        Department of Parks and Recreation      Maintenance or Facility
# 3        Department of Parks and Recreation      Maintenance or Facility
# 4           New York City Police Department                 Noise - Park
# 5        Department of Parks and Recreation      Violation of Park Rules
# 6           New York City Police Department                 Noise - Park
# 7           New York City Police Department                 Noise - Park
# 8           New York City Police Department                 Noise - Park
# 9        Department of Parks and Recreation      Violation of Park Rules
# 10          New York City Police Department                 Noise - Park
# 11       Department of Parks and Recreation             Animal in a Park
# 12       Department of Parks and Recreation                 DPR Internal
# 13          New York City Police Department                      Vending
# 14       Department of Parks and Recreation             Animal in a Park
# 15  Department of Health and Mental Hygiene   Beach/Pool/Sauna Complaint
# 16          New York City Police Department                 Noise - Park
# 17       Department of Parks and Recreation             Animal in a Park
# 18       Department of Parks and Recreation      Violation of Park Rules
# 19          New York City Police Department      Noise - Street/Sidewalk
#
#                       Descriptor    Location Type           Landmark Borough  \
# 0      Other (complaint details)  Street/Sidewalk  WOODLAWN CEMETERY   BRONX
# 1   Commercial Overnight Parking  Street/Sidewalk  WOODLAWN CEMETERY   BRONX
# 2             Hours of Operation  Street/Curbside         DEVOE PARK   BRONX
# 3            Structure - Indoors             Park         BRONX PARK   BRONX
# 4               Loud Music/Party  Park/Playground        HAFFEN PARK   BRONX
# 5    BBQ Outside Authorized Area             Park      BARRETTO PARK   BRONX
# 6               Loud Music/Party  Park/Playground        BRIDGE PARK   BRONX
# 7               Loud Music/Party  Park/Playground     SOUNDVIEW PARK   BRONX
# 8               Loud Music/Party  Park/Playground         DEVOE PARK   BRONX
# 9       Unsafe Use of Playground             Park    PELHAM BAY PARK   BRONX
# 10              Loud Music/Party  Park/Playground        RAINEY PARK   BRONX
# 11             Removing Wildlife             Park    PELHAM BAY PARK   BRONX
# 12                  Aided/Injury             Park       CROTONA PARK   BRONX
# 13                    Unlicensed  Park/Playground   MACOMBS DAM PARK   BRONX
# 14               Domestic Strays             Park       CROTONA PARK   BRONX
# 15              Beach/Pool Water            Beach      ORCHARD BEACH   BRONX
# 16              Loud Music/Party  Park/Playground         DEVOE PARK   BRONX
# 17             Removing Wildlife             Park     CLAREMONT PARK   BRONX
# 18            Unlicensed Vendors             Park          BRONX ZOO   BRONX
# 19              Loud Music/Party  Street/Sidewalk     YANKEE STADIUM   BRONX
#
#    Incident Zip     Latitude     Longitude  \
# 0         10467   40.8888923   -73.8725547
# 1         10467   40.8888923   -73.8725547
# 2         10468   40.8631302  -73.90654452
# 3         10467  40.85666488  -73.87579761
# 4         10469  40.87368343  -73.83916591
# 5         10474  40.81285044   -73.8886751
# 6         10453  40.84594143  -73.92742356
# 7         10473  40.81773577  -73.87501764
# 8         10468   40.8631302  -73.90654452
# 9         10465  40.85690624   -73.8248876
# 10        10459  40.81909159  -73.89717306
# 11        10465  40.85690624   -73.8248876
# 12        10457  40.83794057  -73.89525384
# 13        10452  40.82973197   -73.9287168
# 14        10457  40.83794057  -73.89525384
# 15        10464  40.86582898  -73.79319996
# 16        10468   40.8631302  -73.90654452
# 17        10457  40.84031409  -73.90731745
# 18        10460  40.85023185  -73.87632289
# 19        10452   40.8296455  -73.92650544
#
#                                     Location
# 0    (40.88889230263962, -73.87255469830917)
# 1    (40.88889230263962, -73.87255469830917)
# 2   (40.863130202365284, -73.90654451754935)
# 3    (40.85666487533718, -73.87579760930149)
# 4    (40.87368343276026, -73.83916591245767)
# 5    (40.81285043551196, -73.88867510043575)
# 6    (40.84594142686875, -73.92742355752964)
# 7   (40.817735769859965, -73.87501763502273)
# 8   (40.863130202365284, -73.90654451754935)
# 9     (40.8569062428053, -73.82488760016611)
# 10    (40.8190915908639, -73.89717305973416)
# 11    (40.8569062428053, -73.82488760016611)
# 12   (40.83794057379697, -73.89525384010201)
# 13   (40.82973197149275, -73.92871679858054)
# 14   (40.83794057379697, -73.89525384010201)
# 15  (40.865828984810776, -73.79319996009694)
# 16  (40.863130202365284, -73.90654451754935)
# 17   (40.84031409465535, -73.90731745202085)
# 18   (40.85023185062718, -73.87632289476633)
# 19   (40.829645497269496, -73.9265054412993)

# %%
# Count the total number of complaints in the data set
complaint_count = len(the311_df['Unique Key'])
complaint_count
# Out:
# 814

# %%
# Check out the Top 5 Complaint Types Overall 
top5_comps = the311_df['Complaint Type'].value_counts().head()
top5_comps_df = pd.DataFrame(top5_comps)
top5_comps_df
# Out:
#                          Complaint Type
# Noise - Park                        178
# DPR Internal                        114
# Violation of Park Rules             106
# Animal in a Park                     71
# Maintenance or Facility              70

# %%
# Check out the Botoom 5 Complaint Types Overall 
top5_comps = the311_df['Complaint Type'].value_counts().tail()
top5_comps_df = pd.DataFrame(top5_comps)
top5_comps_df
# Out:
#                            Complaint Type
# For Hire Vehicle Report                 1
# New Tree Request                        1
# Public Payphone Complaint               1
# Street Sign - Missing                   1
# Mold                                    1

# %%
# Make a Bar Graph of the Top 5 Overall Complaint Types
top5types = ["Noise - Park", "DPR Internal", "Violation of Park Rules", "Animal in a Park", "Maintenance or Facility"]
typecounts = [178, 114, 106, 71, 70]
x_axis = np.arange(len(typecounts))

# Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.bar(top5types, typecounts, align="center", color=['orangered', 'turquoise', 'peru', 'cornflowerblue', 'gold'], alpha=0.95)
plt.title("Top 5 Complaint Types Overall (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel("Types", fontdict = {'fontsize': 18, 'fontweight': 'bold'})
plt.ylabel("Counts", fontdict = {'fontsize': 18, 'fontweight': 'bold'})
plt.xticks(x_axis, top5types, rotation=23)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(typecounts)+0.4)
plt.show()

# %%
# Yay! Now turn it into a pie chart with %s!
top5types = ["Noise - Park", "DPR Internal", "Violation of Park Rules", "Animal in a Park", "Maintenance or Facility"]
typecounts = [178, 114, 106, 71, 70]
colors = ["tomato", "paleturquoise", "chocolate", "orchid", "blanchedalmond"]
explode = (0.125,0,0,0,0)

# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("Top 5 Complaint Types Overall", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.pie(typecounts, textprops={'fontsize': 15}, explode=explode, labels=top5types, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=8,)
plt.axis("equal")
plt.show()

# %%
# K, now make a scatter plot of the Top 5's -vs- the Bottom 5's
top5cts = [178, 114, 106, 71, 70]
bot5cts = [1,1,1,1,1]
x_limit = 200
x_axis = np.arange(0, x_limit)

# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("Top/Bottom 5 Test", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.scatter([178, 114, 106, 71, 70],[1,1,1,1,1],s=5000, marker = '*', facecolors='peru', edgecolors="black")
plt.ylim(-2.5, 10)
plt.xlim(0, x_limit)
plt.show()

#meh

# %%
# Let's take a closer look at what the Complaint Types mean

# Expand the Top 5 Complaint Type DataFrame
top5_comps = top5_comps.index.values
top5_comps_df = the311_df.loc[the311_df['Complaint Type'].isin(top5_comps)]
top5_comps_df.count()  
top5_comps_df
# Out:
#     Unique Key      Month     Created Date  \
# 259   39647395       July   7/5/2018 13:03
# 518   40414405  September  9/29/2018 20:07
# 547   40497719    October  10/9/2018 13:10
# 584   38835963      April   4/1/2018 12:55
# 740   39874533       July  7/30/2018 12:04
#
#                                            Agency Name  \
# 259                       Department of Transportation
# 518  Department of Information Technology and Telec...
# 547            Department of Health and Mental Hygiene
# 584                 Department of Parks and Recreation
# 740                      Taxi and Limousine Commission
#
#                 Complaint Type                        Descriptor  \
# 259      Street Sign - Missing                     Other/Unknown
# 518  Public Payphone Complaint                 Damaged Telephone
# 547                       Mold  Public Complaint - Comm Location
# 584           New Tree Request                   For One Address
# 740    For Hire Vehicle Report        Car Service Company Report
#
#            Location Type               Landmark    Borough Incident Zip  \
# 259               Street       GRAND ARMY PLAZA   BROOKLYN        11238
# 518  Street and Sidewalk  MADISON SQUARE GARDEN  MANHATTAN        10001
# 547  Commercial Building           TIMES SQUARE  MANHATTAN        10036
# 584               Street              CITY HALL  MANHATTAN        10007
# 740               Street          J F K AIRPORT     QUEENS        11430
#
#         Latitude     Longitude                                  Location
# 259  40.67399127  -73.97011778   (40.67399126989863, -73.97011777647462)
# 518    40.750475  -73.99336993   (40.75047500123587, -73.99336992791751)
# 547  40.75658179  -73.98963708  (40.756581786411466, -73.98963708106945)
# 584  40.71274564   -74.0060095   (40.71274563665573, -74.00600949796177)
# 740  40.64832049  -73.78828125   (40.64832048620134, -73.78828125130184)

# %%
# Now, let's group and sort by Month 
comp_descs = the311_df.loc[:,['Month','Borough','Complaint Type', 'Descriptor', 'Landmark','Location Type']]
comp_descs
comp_descs_df = the311_df.groupby(['Month'])
comp_descs_df = comp_descs_df.count()
comp_descs_df = comp_descs_df.sort_values('Month', ascending=False)
comp_descs_df
# Out:
#            Unique Key  Created Date  Agency Name  Complaint Type  Descriptor  \
# Month
# September          89            89           89              89          89
# October            64            64           64              64          64
# November           53            53           53              53          53
# May                86            86           86              86          86
# March              36            36           36              36          36
# June              118           118          118             118         118
# July              133           133          133             133         133
# January            19            19           19              19          19
# February           20            20           20              20          20
# December           35            35           35              35          35
# August            116           116          116             116         116
# April              45            45           45              45          45
#
#            Location Type  Landmark  Borough  Incident Zip  Latitude  \
# Month
# September             89        89       89            89        89
# October               64        64       64            64        64
# November              53        53       53            53        53
# May                   86        86       86            86        86
# March                 36        36       36            36        36
# June                 118       118      118           118       118
# July                 133       133      133           133       133
# January               19        19       19            19        19
# February              20        20       20            20        20
# December              35        35       35            35        35
# August               116       116      116           116       116
# April                 45        45       45            45        45
#
#            Longitude  Location
# Month
# September         89        89
# October           64        64
# November          53        53
# May               86        86
# March             36        36
# June             118       118
# July             133       133
# January           19        19
# February          20        20
# December          35        35
# August           116       116
# April             45        45

# %%
# Make a Bar Graph of the # of Complaints by Month
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monthcounts = [19, 20, 36, 45, 86, 118, 133, 116, 89, 64, 53, 35]
colors = ['lightblue','mediumvioletred', 'mediumspringgreen', 'mediumslateblue','gold','lime',
          'tomato','dodgerblue','purple', 'darkorange', 'sienna', 'crimson']                                                                            
x_axis = np.arange(len(monthcounts))

# Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.bar(months, monthcounts, align="center", color=colors, alpha=0.95)
plt.title("# of Complaints by Month (2018)", fontdict = {'fontsize': 25, 'fontweight': 'bold'})
plt.xlabel("Month", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel("Counts", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.xticks(x_axis, months, rotation=0)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(monthcounts)+0.4)
plt.show()

# %%
#Now, make a line graph 
plt.figure(figsize = (15,10))
plt.title("# of Complaints by Month (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.plot(months, monthcounts, color='orangered', linewidth= 10.0, label = '')
plt.show()

# %%
# Yay! Now turn it into a pie chart with %s!
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monthcounts = [19, 20, 36, 45, 86, 118, 133, 116, 89, 64, 53, 35]
colors = ['lightblue','mediumvioletred', 'mediumspringgreen', 'mediumslateblue','gold','lime',
          'tomato','dodgerblue','purple', 'darkorange', 'sienna', 'crimson']   
explode = (0,0,0,0,0,0.125, 0.125, 0.125, 0,0,0,0)

# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("# of Complaints by Month (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.pie(monthcounts, textprops={'fontsize': 15}, explode=explode, labels=months, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=8,)
plt.axis("equal")
plt.show()

# %%
# Checkout the data by Borough
borough_comps = the311_df['Borough'].value_counts().head()
borough_comps_df = pd.DataFrame(borough_comps)
borough_comps_df
# Out:
#                Borough
# MANHATTAN          298
# QUEENS             184
# BROOKLYN           173
# BRONX              124
# STATEN ISLAND       35

# %%
# Make a Bar Graph of the Top 5 Overall Complaint Types
boroughs = ["MANHATTAN", "QUEENS", "BROOKLYN", "BRONX", "STATEN ISLAND"]
borcounts = [298, 184, 173, 124, 35]
x_axis = np.arange(len(borcounts))

# Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.bar(boroughs, borcounts, align="center", color=['peru', 'turquoise', 'black', 'orchid', 'coral'], alpha=0.95)
plt.title("# of Complaints by Borough (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel("Borough", fontdict = {'fontsize': 18, 'fontweight': 'bold'})
plt.ylabel("Counts", fontdict = {'fontsize': 18, 'fontweight': 'bold'})
plt.xticks(x_axis, boroughs, rotation=23)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(borcounts)+0.4)
plt.show()

# %%
# Yay! Now turn it into a pie chart with %s!
boroughs = ["MANHATTAN", "QUEENS", "BROOKLYN", "BRONX", "STATEN ISLAND"]
borcounts = [298, 184, 173, 124, 35]
colors = ['peru', 'turquoise', 'gray', 'orchid', 'coral']
explode = (0.125,0,0,0,0)

# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("# of Complaints by Borough (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.pie(borcounts, textprops={'fontsize': 15}, explode=explode, labels=boroughs, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=8,)
plt.axis("equal")
plt.show()

# %%
# borcounts = 298+184+173+124+35
# borcounts

# %%
#Now, make a line graph 
plt.figure(figsize = (15,10))
plt.title("# of Complaints by Borough (2018)", fontdict = {'fontsize': 20, 'fontweight': 'bold'})
plt.plot(boroughs, borcounts, color='darkgoldenrod', linewidth= 10.0, label = '')
plt.show()

# %%
#So, what kind of complaints are they? 

# Next, Top 5 Complaint Descriptors 
top5_compdescs = the311_df['Descriptor'].value_counts().head()
top5_compdescs_df = pd.DataFrame(top5_compdescs)
top5_compdescs_df
# Out:
#                         Descriptor
# Loud Music/Party               200
# Aided/Injury                    91
# Obstructing Public Use          43
# Unlicensed Vendors              41
# Driver Complaint                32

# %%
# And the bottom 5 
top5_compdescs = the311_df['Descriptor'].value_counts().tail()
top5_compdescs_df = pd.DataFrame(top5_compdescs)
top5_compdescs_df
# Out:
#                                   Descriptor
# Commercial Overnight Parking               1
# Sewage                                     1
# Bag/Wallet                                 1
# Blocked Bike Lane                          1
# Public Complaint - Comm Location           1

# %%
# K, now expand that DataFrame, hunnay
top5_compdescs = top5_compdescs.index.values
top5_compdescs_df = the311_df.loc[the311_df['Descriptor'].isin(top5_compdescs)]
top5_compdescs_df.count()  
top5_compdescs_df
# Out:
#     Unique Key     Month      Created Date  \
# 1     39406030      June    6/8/2018 14:08
# 151   40520940   October  10/11/2018 19:32
# 375   40921794  November  11/13/2018 14:08
# 511   39720730      July   7/14/2018 13:00
# 547   40497719   October   10/9/2018 13:10
#
#                                  Agency Name      Complaint Type  \
# 1            New York City Police Department     Illegal Parking
# 151  Department of Health and Mental Hygiene  Food Establishment
# 375          New York City Police Department     Illegal Parking
# 511            Taxi and Limousine Commission      Found Property
# 547  Department of Health and Mental Hygiene                Mold
#
#                            Descriptor               Location Type  \
# 1        Commercial Overnight Parking             Street/Sidewalk
# 151                            Sewage  Restaurant/Bar/Deli/Bakery
# 375                 Blocked Bike Lane             Street/Sidewalk
# 511                        Bag/Wallet                        Taxi
# 547  Public Complaint - Comm Location         Commercial Building
#
#                  Landmark    Borough Incident Zip     Latitude     Longitude  \
# 1       WOODLAWN CEMETERY      BRONX        10467   40.8888923   -73.8725547
# 151       BARCLAYS CENTER   BROOKLYN        11217    40.682817  -73.97554013
# 375          CENTRAL PARK  MANHATTAN        10000  40.78229521  -73.96519444
# 511  PENNSYLVANIA STATION  MANHATTAN        10121  40.75006595  -73.99210676
# 547          TIMES SQUARE  MANHATTAN        10036  40.75658179  -73.98963708
#
#                                      Location
# 1     (40.88889230263962, -73.87255469830917)
# 151   (40.68281699836376, -73.97554013353896)
# 375  (40.782295208794295, -73.96519444362545)
# 511    (40.75006595421169, -73.9921067617765)
# 547  (40.756581786411466, -73.98963708106945)

# %%
# Make a Bar Graph of the Top 5 Complaint Descriptors
desctypes = ["Loud Music/Party", "Aided/Injury", "Obstructing Public Use", "Unlicensed Vendors", "Driver Complaint"]
typecounts = [200, 91, 43, 41, 32]
x_axis = np.arange(len(typecounts))


# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.bar(desctypes, typecounts, align="center", color=['Fuchsia', 
                                                     'peru', 
                                                     'darkmagenta', 
                                                     'orangered',
                                                     'indigo'], alpha=0.95)
plt.title("Top 5 Complaint Type Descriptors", fontdict = {'fontsize': 25, 'fontweight': 'bold'})
plt.xlabel("Descriptors", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel("Counts", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.xticks(x_axis, desctypes, rotation=23)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(typecounts)+0.4)
plt.show()

# %%
# Yay! Now turn it into a pie chart with %s!
desctypes = ["Loud Music/Party", "Aided/Injury", "Obstructing Public Use", "Unlicensed Vendors", "Driver Complaint"]
typecounts = [200, 91, 43, 41, 32]
colors = ["fuchsia", "peru", "darkmagenta", "orangered", "indigo"]
explode = (0.125,0,0,0,0)

# Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("Top 5 Complaint Descriptors", fontdict = {'fontsize': 25, 'fontweight': 'bold'})
plt.pie(typecounts, textprops={'fontsize': 15}, explode=explode, labels=desctypes, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=45,)
plt.axis("equal")
plt.show()

# %%
# Ok, cool. Next, let's look at the location types

# Next, Top 5 Complaint Descriptors 
complocs = the311_df['Location Type'].value_counts().head()
complocs_df = pd.DataFrame(complocs)
complocs_df
# Out:
#                  Location Type
# Park                       281
# Park/Playground            193
# Street/Sidewalk            116
# Street                      94
# Street/Curbside             37

# %%
# K, now the bottom 5
complocs = the311_df['Location Type'].value_counts().tail()
complocs_df = pd.DataFrame(complocs)
complocs_df
# Out:
#                      Location Type
# Overpass                         1
# Street and Sidewalk              1
# Crosswalk                        1
# Vacant Lot/Property              1
# Government Building              1

# %%
# Make a Bar Graph of the Top 5 Complaint Location Types
loctypes = ["Park", "Park/Playground", "Street/Sidewalk", "Street", "Street/Curbside"]
loccounts = [281, 193, 116, 94, 37]
x_axis = np.arange(len(loccounts))


# # Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.bar(loctypes, loccounts, align="center", color=['black', 
                                                     'orchid', 
                                                     'peru', 
                                                     'cornflowerblue',
                                                     'lightsalmon'], alpha=0.95)
plt.title("Top 5 Complaint Location Types", fontdict = {'fontsize': 25, 'fontweight': 'bold'})
plt.xlabel("Descriptors", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel("Counts", fontdict = {'fontsize': 15, 'fontweight': 'bold'})
plt.xticks(x_axis, loctypes, rotation=23)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(loccounts)+0.4)
plt.show()

# %%
# Yay! Now turn it into a pie chart with %s!
loctypes = ["Park", "Park/Playground", "Street/Sidewalk", "Street", "Street/Curbside"]
loccounts = [281, 193, 116, 94, 37]
colors = ["black", "orchid", "peru", "cornflowerblue", "lightsalmon"]
explode = (0.125,0,0,0,0)
Over
# Plot that graph and make it nice, mmmk?
plt.figure(figsize = (15,10))
plt.title("Top 5 Complaint Location Types", fontdict = {'fontsize': 25, 'fontweight': 'bold'})
plt.pie(loccounts, textprops={'fontsize': 15}, explode=explode, labels=loctypes, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=45,)
plt.axis("equal")
plt.show()
